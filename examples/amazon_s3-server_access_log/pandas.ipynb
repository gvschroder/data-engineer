# %%
import pandas as pd
import re

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
patterns = [
    "(\S+)\s", 
    "(\S+)\s",
    "\[([^\]]+)\]\s",
    "(\S+)\s",
    "(\S+)\s",
    "(\S+)\s",
    "(\S+)\s",
    "(\S+)\s",
    '(-|"-"|"\S+ \S+ (?:-|\S+)")\s',
    "(\S+)\s",
    "(\S+)\s",
    "(\S+)\s",
    "(\S+)\s",
    "(\S+)\s",
    "(\S+)\s",
    '(-|"[^"]+")\s',
    '(-|"[^"]+")\s',
    "(\S+)\s",
    "(\S+)\s",
    "(\S+)\s",
    "(\S+)\s",
    "(\S+)\s",
    "(\S+)\s",
    "(\S+)"
]
column_names = [
    'bucket_owner', 
    'bucket',
    'time',
    'remote_ip',
    'requester',
    'request_id',
    'operation',
    'key',
    'request_uri',
    'http_status',
    'error_code',
    'bytes_sent',
    'object_size',
    'total_time',
    'turn_around_time',
    'referer',
    'user_agent',
    'version_id',
    'host_id',
    'signature_version',
    'cipher_suite',
    'authentication_type',
    'host_header',
    'tls_version'
]

# %%
df = pd.read_csv('./assets/s3_server_access_log.txt', sep='\t', header=None)
df.rename(columns={0: "data"}, inplace=True)

log_pattern = re.compile(re.compile("".join(patterns)))
df = df.data.str.extract(log_pattern)
df.columns = column_names
df
# Out:
#                                                        bucket_owner  \
# 0  79a59df900b949e55d96a1e698fbacedfd6e09d98eacf8f8d5218e7cd47ef2be
# 1  79a59df900b949e55d96a1e698fbacedfd6e09d98eacf8f8d5218e7cd47ef2be
# 2  79a59df900b949e55d96a1e698fbacedfd6e09d98eacf8f8d5218e7cd47ef2be
# 3  79a59df900b949e55d96a1e698fbacedfd6e09d98eacf8f8d5218e7cd47ef2be
# 4  79a59df900b949e55d96a1e698fbacedfd6e09d98eacf8f8d5218e7cd47ef2be
#
#               bucket                        time  remote_ip  \
# 0  awsexamplebucket1  06/Feb/2019:00:00:38 +0000  192.0.2.3
# 1  awsexamplebucket1  06/Feb/2019:00:00:38 +0000  192.0.2.3
# 2  awsexamplebucket1  06/Feb/2019:00:00:38 +0000  192.0.2.3
# 3  awsexamplebucket1  06/Feb/2019:00:01:00 +0000  192.0.2.3
# 4  awsexamplebucket1  06/Feb/2019:00:01:57 +0000  192.0.2.3
#
#                                                           requester  \
# 0  79a59df900b949e55d96a1e698fbacedfd6e09d98eacf8f8d5218e7cd47ef2be
# ...
